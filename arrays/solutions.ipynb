# %%
#arrays

a = [12,23,34,45,56,78]
a

for t in a:
    print(t,end=',')
# Out:
# 12,23,34,45,56,78,

# %%
#append and por and remore
a.append("ahtisham")
print(f"After appending, the list is as: {a}")
b = a.pop()
print(f"AFter popping: {a}")
print(b)
print(12222 in a)
# Out:
# After appending, the list is as: [12, 23, 34, 45, 56, 78, 'ahtisham']
# AFter popping: [12, 23, 34, 45, 56, 78]
# ahtisham
# False

# %%
# Syntax: map(function, iterable)
data = list(map(int, input("Enter data: ").split()))
data
# Out:
# [12]

# %%
import sys
data = []
for i in range(10):
    data.append(i)
    print(f"Items: {len(data)}, Memory: {sys.getsizeof(data)} bytes")
# Out:
# Items: 1, Memory: 88 bytes
# Items: 2, Memory: 88 bytes
# Items: 3, Memory: 88 bytes
# Items: 4, Memory: 88 bytes
# Items: 5, Memory: 120 bytes
# Items: 6, Memory: 120 bytes
# Items: 7, Memory: 120 bytes
# Items: 8, Memory: 120 bytes
# Items: 9, Memory: 184 bytes
# Items: 10, Memory: 184 bytes

# %%
#Reversing an array in python
a = [12,23,34,45,56,67,78]
for i in range (len(a)//2):
    k = a[i] 
    a[i] = a[len(a)-i-1]
    a[len(a)-i-1] = k

print(a)
# Out:
# [78, 67, 56, 45, 34, 23, 12]

# %%
a = [12,12,23,]
len(a)
# Out:
# 3

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 a = " "
#       2 for i in range (3):
# ----> 3     a.replace(input(
#       4     ))
#       5 print(a)
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
# Out:
# 0
# 1
# 2
# 3
# 4
